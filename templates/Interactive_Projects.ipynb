# %% [markdown]
# # Revisión y Ajuste de Proyectos Interactivos con Inputs para el Usuario
#
# ---
#
# ## 1. NLP (Procesamiento de Lenguaje Natural)
#
# - **1.1 Extracción de frases clave con Ngrams**
# - **1.2 Análisis de sentimiento en tweets personalizados**
# - **1.3 Resumen automático de texto**
# - **1.4 Chatbot para ayuda en navegación del sitio (no proyecto NLP especial)**
#
# ---
#
# ## 2. Series de Tiempo
#
# - **2.1 Predicción de estacionalidad univariada (AGREGAR: INTERVALOS DE CONFIANZA, PREDICCION DE TENDENCIA Y RUIDO (p.ej., suavizado exponencial simple o Holt-Winters))**
# - **2.2 autocorrelacion, descripcion, clusterizacion y deteccion de anomalias de serie univariada**
# - **2.3 clusterizacion multivariada**
# - **2.4 analisis de correlacion cruzada (AGREGAR CAUSALIDAD SIMPLE)**
#
# ---
#
# ## 3. Datos Públicos
#
# - **3.1 Consulta y visualización de datos del World Bank**
# - **3.2 Datos meteorológicos históricos**
# - **3.3 Datos Financieros**
#
# ---
#
# ## 4. Datos Sociales
#
# - **4.1 Análisis de conversaciones de WhatsApp**
# - **4.2 Análisis de hashtags y temas en Twitter**
# - **4.3 Análisis de datos de YouTube**
#
# ---
#
# ## 5. Computer Vision
#
# - **5.1 Transformaciones de imágenes simples**
# - **5.2 OCR básico para extracción de texto de imágenes**
# - **5.3 Detección de bordes y filtros visuales**
#
# ---
#
# ## 6. Audio y Señales
#
# - **6.1 Clasificación sencilla de género o emoción en voz**
# - **6.2 Conversión voz a texto**
# - **6.3 Visualización de espectrograma y análisis de frecuencias**
#
# ---
#
# ## 8. Reinforcement Learning y Simulaciones
#
# - **8.1 Juegos simples para experimentar RL**
# - **8.2 Trading bot**
